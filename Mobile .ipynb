# %% [markdown]
# # Importing necessary libraries

# %%
import numpy as nu
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing dataset

# %%
mob=pd.read_csv("C:/Users/Sanyam/Downloads/Mobile dataset.csv")
mob
# Out:
#       brand           model base_color processor screen_size  ROM  RAM  \
# 0     Apple       iPhone SE      Black     Water  Very Small   64    2
# 1     Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2     Apple       iPhone SE        Red     Water  Very Small   64    2
# 3     Apple       iPhone XR     Others       iOS      Medium   64    3
# 4     Apple       iPhone 12        Red   Ceramic      Medium  128    4
# ..      ...             ...        ...       ...         ...  ...  ...
# 425  Xiaomi     Redmi 6 Pro      Black  Qualcomm       Small   32    3
# 426  Xiaomi     Redmi 6 Pro        Red  Qualcomm       Small   64    4
# 427  Xiaomi      Mi 11 Lite     Others  Qualcomm       Large  128    6
# 428  Xiaomi   Redmi 8A Dual       Blue  Qualcomm      Medium   32    3
# 429  Xiaomi     Redmi 6 Pro       Blue  Qualcomm       Small   32    3
#
#      display_size  num_rear_camera  num_front_camera  battery_capacity  \
# ...

# %%
# to show no. of elements
print(mob.size)
# Out:
# 6880

# %%
# to check rows and columns 
print(mob.shape)
# Out:
# (430, 16)

# %%
# columns name
print(list(mob.columns))
# Out:
# ['brand', 'model', 'base_color', 'processor', 'screen_size', 'ROM', 'RAM', 'display_size', 'num_rear_camera', 'num_front_camera', 'battery_capacity', 'ratings', 'num_of_ratings', 'sales_price', 'discount_percent', 'sales']

# %%
# To check first 5 rows
mob.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  battery_capacity  ratings  \
# 0           4.7                1                 1              1800      4.5
# 1           5.4                2                 1              2815      4.5
# 2           4.7                1                 1              1800      4.5
# 3           6.1                1                 1              2942      4.6
# 4           6.1                2                 1              2815      4.6
#
#    num_of_ratings  sales_price  discount_percent   sales
# ...

# %%
# To check last 5 rows
mob.tail()
# Out:
#       brand          model base_color processor screen_size  ROM  RAM  \
# 425  Xiaomi    Redmi 6 Pro      Black  Qualcomm       Small   32    3
# 426  Xiaomi    Redmi 6 Pro        Red  Qualcomm       Small   64    4
# 427  Xiaomi     Mi 11 Lite     Others  Qualcomm       Large  128    6
# 428  Xiaomi  Redmi 8A Dual       Blue  Qualcomm      Medium   32    3
# 429  Xiaomi    Redmi 6 Pro       Blue  Qualcomm       Small   32    3
#
#      display_size  num_rear_camera  num_front_camera  battery_capacity  \
# 425           5.8                2                 1              4000
# 426           5.8                2                 1              4000
# 427           6.5                3                 1              4250
# 428           6.2                2                 1              5000
# 429           5.8                2                 1              4000
#
#      ratings  num_of_ratings  sales_price  discount_percent  sales
# ...

# %%
# check no. of rows and columnns 
print(mob.shape)
# Out:
# (430, 16)

# %%
# shows basic stats
mob.describe()
# Out:
#               ROM         RAM  display_size  num_rear_camera  \
# count  430.000000  430.000000    430.000000       430.000000
# mean   105.748837    5.320930      6.369767         2.904651
# std     63.164064    2.182635      0.369549         0.952350
# min      8.000000    1.000000      4.700000         1.000000
# 25%     64.000000    4.000000      6.300000         2.000000
# 50%    128.000000    4.000000      6.500000         3.000000
# 75%    128.000000    6.000000      6.500000         4.000000
# max    512.000000   12.000000      7.600000         4.000000
#
#        num_front_camera  battery_capacity     ratings  num_of_ratings  \
# count        430.000000        430.000000  430.000000      430.000000
# mean           1.044186       4529.397674    4.339302    23567.944186
# std            0.227280        986.907252    0.151494    56096.277784
# min            1.000000       1800.000000    3.000000        4.000000
# ...

# %%
# checking count and dtypes
mob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             430 non-null    object
#  1   model             430 non-null    object
#  2   base_color        430 non-null    object
#  3   processor         430 non-null    object
#  4   screen_size       430 non-null    object
#  5   ROM               430 non-null    int64
#  6   RAM               430 non-null    int64
#  7   display_size      430 non-null    float64
#  8   num_rear_camera   430 non-null    int64
#  9   num_front_camera  430 non-null    int64
#  10  battery_capacity  430 non-null    int64
#  11  ratings           430 non-null    float64
#  12  num_of_ratings    430 non-null    int64
#  13  sales_price       430 non-null    int64
#  14  discount_percent  430 non-null    float64
#  15  sales             430 non-null    float64
# ...

# %%
# True represents not null values and false represents null values
mob.notnull()
# Out:
#      brand  model  base_color  processor  screen_size   ROM   RAM  \
# 0     True   True        True       True         True  True  True
# 1     True   True        True       True         True  True  True
# 2     True   True        True       True         True  True  True
# 3     True   True        True       True         True  True  True
# 4     True   True        True       True         True  True  True
# ..     ...    ...         ...        ...          ...   ...   ...
# 425   True   True        True       True         True  True  True
# 426   True   True        True       True         True  True  True
# 427   True   True        True       True         True  True  True
# 428   True   True        True       True         True  True  True
# 429   True   True        True       True         True  True  True
#
#      display_size  num_rear_camera  num_front_camera  battery_capacity  \
# 0            True             True              True              True
# ...

# %%
# Check number of null values in each column
print(mob.isnull().sum())
# there is no null values in this data
# Out:
# brand               0
# model               0
# base_color          0
# processor           0
# screen_size         0
# ROM                 0
# RAM                 0
# display_size        0
# num_rear_camera     0
# num_front_camera    0
# battery_capacity    0
# ratings             0
# num_of_ratings      0
# sales_price         0
# discount_percent    0
# sales               0
# dtype: int64

# %%
# checking null values  with heatmap
sns.heatmap(mob.isnull());

# %%
# checking number of brands
print(mob['brand'].unique())
# five brands are there in this dataset
# Out:
# ['Apple' 'Poco' 'Realme' 'Samsung' 'Xiaomi']

# %%
# how many mobiles each brand has sold?
print(mob['brand'].value_counts())
# Out:
# Realme     138
# Samsung    119
# Xiaomi      61
# Apple       56
# Poco        56
# Name: brand, dtype: int64

# %%
# mobiles sold,through bar chart
mob['brand'].value_counts().plot(kind='bar',edgecolor='black')
plt.xlabel('Brands')
plt.show()

# %%
# number of models sold by each brand
print(mob.groupby(['brand'])['model'].value_counts())
# Out:
# brand   model
# Apple   iPhone XR         18
#         iPhone 12         17
#         iPhone 12 Mini    16
#         iPhone SE          3
#         iPhone 7 Plus      1
#                           ..
# Xiaomi  Redmi 6A           1
#         Redmi 9A           1
#         Redmi Note 4       1
#         Redmi Note 5       1
#         Redmi Y2           1
# Name: model, Length: 120, dtype: int64

# %%
# which base color mostly people prefer ?
sns.countplot(mob['base_color'],edgecolor='black');
# blue

# %%
# which brand has got good and which one has got bad ratings ?
sns.stripplot(mob['brand'],mob['ratings']);
# apple good samsung bad

# %%
# which brand has got more ratings ?
sns.scatterplot(mob['brand'],mob['num_of_ratings']);
# xiaomi

# %%
# most demanded processor??
plt.figure(figsize=(7,7))
a=mob['processor'].value_counts()
a.plot(kind='pie',autopct='%0.1f%%',startangle=45,explode=(0.11,0,0,0,0,0,0));
# Qualcomm

# %%
# how many mobiles having Qualcomm processor were sold??
print("Qualcomm mobiles sold:-->",mob[mob['processor']=='Qualcomm'].shape[0])
# Out:
# Qualcomm mobiles sold:--> 168

# %%
# screen size counts
print(mob['screen_size'].value_counts())
# Out:
# Large         242
# Medium        146
# Small          34
# Very Small      4
# Very Large      4
# Name: screen_size, dtype: int64

# %%
# which screen size mostly people prefer ?
sns.countplot(mob['screen_size'],edgecolor='black');
# blue

# %%
# which brand has highest revenue?(sales price of mobiles )
plt.bar(mob['brand'],mob['sales_price'])
plt.show()

# %%
# see only a particular brand.
mob[mob['brand']=='Apple']
# Out:
#     brand           model base_color processor screen_size  ROM  RAM  \
# 0   Apple       iPhone SE      Black     Water  Very Small   64    2
# 1   Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2   Apple       iPhone SE        Red     Water  Very Small   64    2
# 3   Apple       iPhone XR     Others       iOS      Medium   64    3
# 4   Apple       iPhone 12        Red   Ceramic      Medium  128    4
# 5   Apple       iPhone 12       Blue   Ceramic      Medium   64    4
# 6   Apple       iPhone 12      White   Ceramic      Medium  128    4
# 7   Apple       iPhone 12      Green   Ceramic      Medium   64    4
# 8   Apple       iPhone 12       Blue   Ceramic      Medium  128    4
# 9   Apple       iPhone 12      Black   Ceramic      Medium  128    4
# 10  Apple  iPhone 12 Mini      Black   Ceramic       Small   64    4
# 11  Apple       iPhone 12      Green   Ceramic      Medium  128    4
# 12  Apple  iPhone 12 Mini      White   Ceramic       Small  128    4
# ...

# %%
# apple mobiles which are less than 40K
mob[(mob['brand']=='Apple') & (mob['sales_price']<=40000)]
# Out:
#     brand          model base_color processor screen_size  ROM  RAM  \
# 0   Apple      iPhone SE      Black     Water  Very Small   64    2
# 2   Apple      iPhone SE        Red     Water  Very Small   64    2
# 35  Apple      iPhone SE      White     Water  Very Small   64    2
# 42  Apple       iPhone 8       Gold       iOS  Very Small   64    2
# 43  Apple  iPhone 7 Plus      Black       iOS       Small   32    2
#
#     display_size  num_rear_camera  num_front_camera  battery_capacity  \
# 0            4.7                1                 1              1800
# 2            4.7                1                 1              1800
# 35           4.7                1                 1              1800
# 42           4.7                1                 1              1800
# 43           5.5                2                 1              1800
#
#     ratings  num_of_ratings  sales_price  discount_percent   sales
# 0       4.5           38645        32999              0.17  127.52
# ...

# %%
# how many front cameras each brand offers??
plt.scatter(mob['brand'],mob['num_front_camera'],color='red');

# %%
# how many rear cameras each brand offers??
plt.scatter(mob['brand'],mob['num_rear_camera'],color='green');
